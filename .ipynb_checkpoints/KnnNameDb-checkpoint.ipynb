# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\S.A.H.Mirnia\AppData\Local\Temp\ipykernel_16528\869123740.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('baby-names.csv')
df
# Out:
#         year          name   percent   sex
# 0       1880          John  0.081541   boy
# 1       1880       William  0.080511   boy
# 2       1880         James  0.050057   boy
# 3       1880       Charles  0.045167   boy
# 4       1880        George  0.043292   boy
# ...      ...           ...       ...   ...
# 258000  2008       Elianna  0.000127  girl
# 258001  2020         elham  0.000127  girl
# 258002  2020         zahra  0.000127  girl
# 258003  2020       fatemeh  0.000127  girl
# 258004  2021  fatemehzahra  0.000127  girl
#
# [258005 rows x 4 columns]

# %%
dfd=df[['name','sex']]
dfd
# Out:
#                 name   sex
# 0               John   boy
# 1            William   boy
# 2              James   boy
# 3            Charles   boy
# 4             George   boy
# ...              ...   ...
# 258000       Elianna  girl
# 258001         elham  girl
# 258002         zahra  girl
# 258003       fatemeh  girl
# 258004  fatemehzahra  girl
#
# [258005 rows x 2 columns]

# %% [markdown]
# ## labelencodind

# %%
from sklearn import preprocessing 
dfd['sex'].values
label_encoder = preprocessing.LabelEncoder() 
dfd['sex']= label_encoder.fit_transform(dfd['sex']) 
dfd['sex'].values
# Out:
# C:\Users\S.A.H.Mirnia\AppData\Local\Temp\ipykernel_16528\2447096462.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfd['sex']= label_encoder.fit_transform(dfd['sex'])
# array([0, 0, 0, ..., 1, 1, 1])

# %% [markdown]
# ## fethure encoding

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
x= vectorizer.fit_transform(dfd['name'])
y=dfd['sex'].values
x.shape
# Out:
# (258005, 6786)

# %% [markdown]
# ## splitdata

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# ## train

# %%
neigh = KNeighborsClassifier(n_neighbors=4)
neigh.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %% [markdown]
# ## predict one name

# %%
test= vectorizer.transform(['xavi'])
neigh.predict(test)
# Out:
# array([0])

# %% [markdown]
# ## accuracy

# %%
from sklearn.metrics import accuracy_score
y_pred=neigh.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'دقت  مدل: {accuracy}')
# Out:
# دقت  مدل: 0.926028565337881
